# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Exploratory Data Analysis

# %%
df = pd.read_csv("dataset2.csv")
df.head()
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6123.547647   LEO  CCSFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCSFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCSFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCSFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Class
# 0            0  B0003  -80.577366  28.561857      0
# ...

# %%
sns.catplot(y="PayloadMass", x="FlightNumber", hue="Class", data=df, aspect = 5)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("Pay load Mass (kg)",fontsize=20)
plt.show()

# %%
sns.barplot(y="LaunchSite", x="PayloadMass", hue="Class", data=df)
plt.xlabel("PayloadMass")
plt.ylabel("LaunchSite")
plt.show()

# %%
year=[]
def launchYear(date):
    for i in df["Date"]:
        year.append(i.split("-")[0])
    return year

launchYear(df['Date'])
# Out:
# ['2010',
#  '2012',
#  '2013',
#  '2013',
#  '2013',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020']

# %%
temp = df.copy()
temp['Year'] = year
temp.groupby('Year')['Class'].mean().plot()
# Out:
# <Axes: xlabel='Year'>

# %%
features = df[['FlightNumber', 'PayloadMass', 'Orbit', 'LaunchSite', 'Flights', 'GridFins', 'Reused', 'Legs', 'LandingPad', 'Block', 'ReusedCount', 'Class']]
features.head()
# Out:
#    FlightNumber  PayloadMass Orbit    LaunchSite  Flights  GridFins  Reused  \
# 0             1  6123.547647   LEO  CCSFS SLC 40        1     False   False
# 1             2   525.000000   LEO  CCSFS SLC 40        1     False   False
# 2             3   677.000000   ISS  CCSFS SLC 40        1     False   False
# 3             4   500.000000    PO   VAFB SLC 4E        1     False   False
# 4             5  3170.000000   GTO  CCSFS SLC 40        1     False   False
#
#     Legs LandingPad  Block  ReusedCount  Class
# 0  False        NaN    1.0            0      0
# 1  False        NaN    1.0            0      0
# 2  False        NaN    1.0            0      0
# 3  False        NaN    1.0            0      0
# 4  False        NaN    1.0            0      0

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['PayloadMass'], kde=True, color='green')
plt.title('Distribution of Payload Mass')
plt.xlabel('Payload Mass (kg)')
plt.ylabel('Frequency')
plt.show()

# %%
features_one_hot = features.astype('float64', errors='ignore')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='FlightNumber', y='PayloadMass', hue='Orbit', style='LaunchSite', data=df)
plt.title('Payload Mass vs. Flight Number')
plt.xlabel('Flight Number')
plt.ylabel('Payload Mass (kg)')
plt.legend(title='Orbit/Launch Site', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
